# %% [markdown]
# <a href="https://colab.research.google.com/github/ssiddiqa/Django-Practice/blob/main/Hyperbola.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

x = np.linspace(-9, 9, 400)
y = np.linspace(-5, 5, 400)
x, y = np.meshgrid(x, y)

# function to plot the origin axes
def axes():
    plt.axhline(0, alpha=.1)
    plt.axvline(0, alpha=.1)

# %%
a = 3
b = 2
axes()
plt.contour(x, y,(x**2/a**2 - y**2/b**2), [1], colors='k')
plt.show()
